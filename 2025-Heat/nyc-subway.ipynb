# %%
import pandas as pd

# %%
df = pd.read_csv("D:/heat/MTA_Subway_Origin-Destination_Ridership_Estimate__2024_20250627.csv")

# %%
# Out:
#            Year  Month Day of Week  Hour of Day               Timestamp  \
# 0          2024      8      Monday            8  08/05/2024 08:00:00 AM
# 1          2024      8      Monday            8  08/05/2024 08:00:00 AM
# 2          2024      8      Monday            8  08/05/2024 08:00:00 AM
# 3          2024      8      Monday            8  08/05/2024 08:00:00 AM
# 4          2024      8      Monday            8  08/05/2024 08:00:00 AM
# ...         ...    ...         ...          ...                     ...
# 116279064  2024      8      Monday            5  08/05/2024 05:00:00 AM
# 116279065  2024      8      Monday            6  08/05/2024 06:00:00 AM
# 116279066  2024      8      Monday            7  08/05/2024 07:00:00 AM
# 116279067  2024      8      Monday            7  08/05/2024 07:00:00 AM
# 116279068  2024      8      Monday            8  08/05/2024 08:00:00 AM
#
#            Origin Station Complex ID         Origin Station Complex Name  \
# ...

# %%
# Timestamp is datetime type
df["Timestamp"] = pd.to_datetime(df["Timestamp"])

# Min and Max
min_time = df["Timestamp"].min()
max_time = df["Timestamp"].max()

print(f"📅 Earliest timestamp: {min_time}")
print(f"📅 Latest timestamp: {max_time}")
# Out:
# 📅 Earliest timestamp: 2024-01-08 00:00:00
# 📅 Latest timestamp: 2024-12-08 23:00:00

# %%
df["Timestamp"].unique()
# Out:
# array(['2024-08-05T08:00:00.000000000', '2024-08-05T09:00:00.000000000',
#        '2024-08-05T10:00:00.000000000', ...,
#        '2024-01-13T04:00:00.000000000', '2024-01-11T02:00:00.000000000',
#        '2024-01-13T03:00:00.000000000'], dtype='datetime64[ns]')

# %%
# Unique values 추출 후 정렬
unique_timestamps = pd.DataFrame(sorted(df["Timestamp"].unique()), columns=["Unique Timestamps"])
unique_timestamps.to_csv("unique_timestamps.csv", index=False)

# %%
# Filter: June to August 2024
df_summer = df[(df["Timestamp"] >= "2024-06-01") & (df["Timestamp"] < "2024-09-01")]
df_summer
# Out:
#            Year  Month Day of Week  Hour of Day           Timestamp  \
# 0          2024      8      Monday            8 2024-08-05 08:00:00
# 1          2024      8      Monday            8 2024-08-05 08:00:00
# 2          2024      8      Monday            8 2024-08-05 08:00:00
# 3          2024      8      Monday            8 2024-08-05 08:00:00
# 4          2024      8      Monday            8 2024-08-05 08:00:00
# ...         ...    ...         ...          ...                 ...
# 116279064  2024      8      Monday            5 2024-08-05 05:00:00
# 116279065  2024      8      Monday            6 2024-08-05 06:00:00
# 116279066  2024      8      Monday            7 2024-08-05 07:00:00
# 116279067  2024      8      Monday            7 2024-08-05 07:00:00
# 116279068  2024      8      Monday            8 2024-08-05 08:00:00
#
#            Origin Station Complex ID         Origin Station Complex Name  \
# 0                                179                   Nostrand Av (A,C)
# ...

# %%
# Sorting
df_sorted = df_summer.sort_values("Timestamp").reset_index(drop=True)
df_sorted
# Out:
#           Year  Month Day of Week  Hour of Day           Timestamp  \
# 0         2024      6      Monday            0 2024-06-03 00:00:00
# 1         2024      6      Monday            0 2024-06-03 00:00:00
# 2         2024      6      Monday            0 2024-06-03 00:00:00
# 3         2024      6      Monday            0 2024-06-03 00:00:00
# 4         2024      6      Monday            0 2024-06-03 00:00:00
# ...        ...    ...         ...          ...                 ...
# 28505093  2024      8      Sunday           23 2024-08-11 23:00:00
# 28505094  2024      8      Sunday           23 2024-08-11 23:00:00
# 28505095  2024      8      Sunday           23 2024-08-11 23:00:00
# 28505096  2024      8      Sunday           23 2024-08-11 23:00:00
# 28505097  2024      8      Sunday           23 2024-08-11 23:00:00
#
#           Origin Station Complex ID        Origin Station Complex Name  \
# 0                               135                     Livonia Av (L)
# ...

# %%
df_sorted.to_csv("nyc_subway_summer.csv", index=False)
