# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # merged

# %%
cm_merged = pd.read_csv("cm_merged.csv")
cm_grouped = cm_merged.groupby(['Checkout Hour', 'Community_x']).size().reset_index(name='Count')
cm_grouped
# Out:
#     Checkout Hour  Community_x  Count
# 0               0            0     36
# 1               0            1     37
# 2               0            2    226
# 3               0            3    154
# 4               1            0     19
# ..            ...          ...    ...
# 91             22            3    266
# 92             23            0     58
# 93             23            1     76
# 94             23            2    237
# 95             23            3    247
#
# [96 rows x 3 columns]

# %%
custom_palette = {
    0: (30/255, 120/255, 230/255),   # blue
    1: (50/255, 160/255, 70/255),    # green
    2: (255/255, 180/255, 40/255),   # orange
    3: (240/255, 100/255, 100/255),  # pink
    4: '#CCA3E1' # purple
}

plt.figure(figsize=(12, 6))

for community in sorted(cm_grouped['Community_x'].unique()):
    subset = cm_grouped[cm_grouped['Community_x'] == community]
    plt.plot(
        subset['Checkout Hour'],
        subset['Count'],
        marker='o',
        linestyle='-',
        color=custom_palette.get(community, 'gray'),
        label=f'{community}'
    )

plt.xlabel('Checkout hour')
plt.ylabel('Usage count')
plt.xticks(range(0, 24))
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(title='Community')
plt.tight_layout()

plt.savefig("cm_merged.png", dpi=300)

plt.show()

# %% [markdown]
# # weekday

# %%
cm_merged = pd.read_csv("cm_weekday.csv")
cm_grouped = cm_merged.groupby(['Checkout Hour', 'Community_x']).size().reset_index(name='Count')
cm_grouped
# Out:
#     Checkout Hour  Community_x  Count
# 0               0            0     18
# 1               0            1     13
# 2               0            2    153
# 3               0            3    105
# 4               1            0      4
# ..            ...          ...    ...
# 90             22            3    200
# 91             23            0     45
# 92             23            1     55
# 93             23            2    188
# 94             23            3    182
#
# [95 rows x 3 columns]

# %%
plt.figure(figsize=(12, 6))

for community in sorted(cm_grouped['Community_x'].unique()):
    subset = cm_grouped[cm_grouped['Community_x'] == community]
    plt.plot(
        subset['Checkout Hour'],
        subset['Count'],
        marker='o',
        linestyle='-',
        color=custom_palette.get(community, 'gray'),
        label=f'{community}'
    )

plt.xlabel('Checkout hour')
plt.ylabel('Usage count')
plt.xticks(range(0, 24))
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(title='Community')
plt.tight_layout()

plt.savefig("cm_weekday.png", dpi=300)

plt.show()

# %% [markdown]
# # weekend

# %%
cm_merged = pd.read_csv("cm_weekend.csv")
cm_grouped = cm_merged.groupby(['Checkout Hour', 'Community_x']).size().reset_index(name='Count')
cm_grouped
# Out:
#      Checkout Hour  Community_x  Count
# 0                0            0     18
# 1                0            1     23
# 2                0            2     75
# 3                0            3     47
# 4                0            4      1
# ..             ...          ...    ...
# 111             23            0     13
# 112             23            1     20
# 113             23            2     53
# 114             23            3     61
# 115             23            4      1
#
# [116 rows x 3 columns]

# %%
plt.figure(figsize=(12, 6))

for community in sorted(cm_grouped['Community_x'].unique()):
    subset = cm_grouped[cm_grouped['Community_x'] == community]
    plt.plot(
        subset['Checkout Hour'],
        subset['Count'],
        marker='o',
        linestyle='-',
        color=custom_palette.get(community, 'gray'),
        label=f'{community}'
    )

plt.xlabel('Checkout hour')
plt.ylabel('Usage count')
plt.xticks(range(0, 24))
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(title='Community')
plt.tight_layout()

plt.savefig("cm_weekend.png", dpi=300)

plt.show()
